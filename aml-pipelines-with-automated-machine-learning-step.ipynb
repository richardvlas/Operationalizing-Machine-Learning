# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.32.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-153963
# aml-quickstarts-153963
# southcentralus
# 6971f5ac-8af1-446e-8034-05acea24681f

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'automl-experiment-bank-marketing'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: automl-experiment-bank-marketing,
# Workspace: quick-starts-ws-153963)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
ws.datasets.keys()
# Out:
# KeysView({'Bank-marketing': DatasetRegistration(id='3e225e48-227c-4403-b264-c311f69ffb9c', name='Bank-marketing', version=1, description='', tags={})})

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [74a7004b][9fe06071-fdba-4253-8564-3ff112e544bf], (This step will run and generate new outputs)
# Submitted PipelineRun 56e6cdad-98bb-4524-9cfb-4e382f990697
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/56e6cdad-98bb-4524-9cfb-4e382f990697?wsid=/subscriptions/6971f5ac-8af1-446e-8034-05acea24681f/resourcegroups/aml-quickstarts-153963/workspaces/quick-starts-ws-153963&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 56e6cdad-98bb-4524-9cfb-4e382f990697
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/56e6cdad-98bb-4524-9cfb-4e382f990697?wsid=/subscriptions/6971f5ac-8af1-446e-8034-05acea24681f/resourcegroups/aml-quickstarts-153963/workspaces/quick-starts-ws-153963&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '56e6cdad-98bb-4524-9cfb-4e382f990697', 'status': 'Completed', 'startTimeUtc': '2021-08-08T14:53:05.93978Z', 'endTimeUtc': '2021-08-08T15:08:05.778599Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg153963.blob.core.windows.net/azureml/ExperimentRun/dcid.56e6cdad-98bb-4524-9cfb-4e382f990697/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=ULHnTwugN%2BAZ4Pxo%2FxkcV%2F3e8iwTgFVOMpDaZ3RlmXo%3D&st=2021-08-08T14%3A44%3A43Z&se=2021-08-08T22%3A54%3A43Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg153963.blob.core.windows.net/azureml/ExperimentRun/dcid.56e6cdad-98bb-4524-9cfb-4e382f990697/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=M0txxHbDBcxfozbAi9NsqHP%2BsiBrBI36jjct7JQhrJ4%3D&st=2021-08-08T14%3A44%3A43Z&se=2021-08-08T22%3A54%3A43Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg153963.blob.core.windows.net/azureml/ExperimentRun/dcid.56e6cdad-98bb-4524-9cfb-4e382f990697/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=moYlKaQpLPOmuMDKhH%2FUzzYraE%2B%2FH0dzs6%2F9SkvASAw%3D&st=2021-08-08T14%3A44%3A43Z&se=2021-08-08T22%3A54%3A43Z&sp=r'}, 'submittedBy': 'ODL_User 153963'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d3a49e17-cada-4314-b0e2-f7e879f8ed26/metrics_data
# Downloaded azureml/d3a49e17-cada-4314-b0e2-f7e879f8ed26/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_3  \
# precision_score_micro                              [0.9071320182094081]
# average_precision_score_macro                      [0.8065229883244922]
# recall_score_micro                                 [0.9071320182094081]
# average_precision_score_micro                      [0.9791945367231853]
# precision_score_macro                              [0.7723958081530135]
# precision_score_weighted                           [0.8991976076061607]
# AUC_macro                                          [0.9392346349984347]
# AUC_micro                                          [0.9781770788959222]
# average_precision_score_weighted                   [0.9505970434373063]
# f1_score_weighted                                  [0.9021127651963996]
# norm_macro_recall                                 [0.43834549418631563]
# f1_score_macro                                     [0.7416848907681176]
# balanced_accuracy                                  [0.7191727470931578]
# matthews_correlation                                [0.488678780261868]
# f1_score_micro                                     [0.9071320182094081]
# weighted_accuracy                                  [0.9537972210153172]
# recall_score_macro                                 [0.7191727470931578]
# recall_score_weighted                              [0.9071320182094081]
# AUC_weighted                                       [0.9392346349984347]
# log_loss                                          [0.18743634958563793]
# accuracy                                           [0.9071320182094081]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_7  \
# precision_score_micro                              [0.9095599393019727]
# average_precision_score_macro                        [0.80981584832691]
# recall_score_micro                                 [0.9095599393019727]
# average_precision_score_micro                      [0.9787227065747729]
# precision_score_macro                              [0.8120054945054944]
# precision_score_weighted                           [0.8967072654204672]
# AUC_macro                                          [0.9372706526108323]
# AUC_micro                                          [0.9777661928566989]
# average_precision_score_weighted                   [0.9510384666971292]
# f1_score_weighted                                  [0.8948846685364892]
# norm_macro_recall                                 [0.31556163135110493]
# f1_score_macro                                     [0.7014585481893716]
# balanced_accuracy                                  [0.6577808156755525]
# matthews_correlation                               [0.4437498458290709]
# f1_score_micro                                     [0.9095599393019727]
# weighted_accuracy                                  [0.9720698851883564]
# recall_score_macro                                 [0.6577808156755525]
# recall_score_weighted                              [0.9095599393019727]
# AUC_weighted                                       [0.9372706526108323]
# log_loss                                           [0.3295472471065043]
# accuracy                                           [0.9095599393019727]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_4  \
# precision_score_micro                              [0.9001517450682853]
# average_precision_score_macro                      [0.7322780686027137]
# recall_score_micro                                 [0.9001517450682853]
# average_precision_score_micro                      [0.9678967718477016]
# precision_score_macro                              [0.7979300898726163]
# precision_score_weighted                           [0.8827113977984437]
# AUC_macro                                          [0.8917637775147402]
# AUC_micro                                          [0.9664244118439445]
# average_precision_score_weighted                   [0.9287424600807893]
# f1_score_weighted                                  [0.8746567304785686]
# norm_macro_recall                                  [0.1865537828310615]
# f1_score_macro                                     [0.6267831475663812]
# balanced_accuracy                                  [0.5932768914155307]
# matthews_correlation                              [0.33340661446628406]
# f1_score_micro                                     [0.9001517450682853]
# weighted_accuracy                                  [0.9763404704059276]
# recall_score_macro                                 [0.5932768914155307]
# recall_score_weighted                              [0.9001517450682853]
# AUC_weighted                                       [0.8917637775147403]
# log_loss                                          [0.25273659528115194]
# accuracy                                           [0.9001517450682853]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_12  \
# precision_score_micro                               [0.9071320182094081]
# average_precision_score_macro                       [0.7798530705146514]
# recall_score_micro                                  [0.9071320182094081]
# average_precision_score_micro                       [0.9749456369318957]
# precision_score_macro                               [0.7913759654992741]
# precision_score_weighted                            [0.8934056886222705]
# AUC_macro                                           [0.9229564117240625]
# AUC_micro                                           [0.9740235469661349]
# average_precision_score_weighted                    [0.9426251093639617]
# f1_score_weighted                                   [0.8943471399847562]
# norm_macro_recall                                   [0.3294053685581284]
# f1_score_macro                                      [0.7042835724240846]
# balanced_accuracy                                   [0.6647026842790642]
# matthews_correlation                                [0.4381342426797269]
# f1_score_micro                                      [0.9071320182094081]
# weighted_accuracy                                   [0.9673206642217882]
# recall_score_macro                                  [0.6647026842790642]
# recall_score_weighted                               [0.9071320182094081]
# AUC_weighted                                        [0.9229564117240625]
# log_loss                                           [0.21264884347539417]
# accuracy                                            [0.9071320182094081]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_5  \
# precision_score_micro                              [0.8883156297420334]
# average_precision_score_macro                      [0.7461319542290542]
# recall_score_micro                                 [0.8883156297420334]
# average_precision_score_micro                      [0.9681615696764874]
# precision_score_macro                              [0.9441408621736491]
# precision_score_weighted                           [0.9007928150046113]
# AUC_macro                                          [0.9001957962163354]
# AUC_micro                                           [0.967608437854753]
# average_precision_score_weighted                   [0.9317708482108872]
# f1_score_weighted                                  [0.8360791405851395]
# norm_macro_recall                               [0.0027100271002709064]
# f1_score_macro                                    [0.47312070913357085]
# balanced_accuracy                                  [0.5013550135501355]
# matthews_correlation                             [0.049063912865329386]
# f1_score_micro                                     [0.8883156297420334]
# weighted_accuracy                                  [0.9843874836349229]
# recall_score_macro                                 [0.5013550135501355]
# recall_score_weighted                              [0.8883156297420334]
# AUC_weighted                                       [0.9001957962163353]
# log_loss                                           [0.2494346637712425]
# accuracy                                           [0.8883156297420334]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_13  \
# precision_score_micro                               [0.7635811836115326]
# average_precision_score_macro                       [0.7229104590457347]
# recall_score_micro                                  [0.7635811836115326]
# average_precision_score_micro                       [0.8113745008522015]
# precision_score_macro                               [0.6197265948856959]
# precision_score_weighted                            [0.8811595610349243]
# AUC_macro                                           [0.8338834892108319]
# AUC_micro                                           [0.8380726764468167]
# average_precision_score_weighted                    [0.9161762873914828]
# f1_score_weighted                                   [0.8024679394546721]
# norm_macro_recall                                  [0.49220334650373165]
# f1_score_macro                                      [0.6295402269487456]
# balanced_accuracy                                   [0.7461016732518658]
# matthews_correlation                               [0.34330694915260923]
# f1_score_micro                                      [0.7635811836115326]
# weighted_accuracy                                   [0.7679208732210829]
# recall_score_macro                                  [0.7461016732518658]
# recall_score_weighted                               [0.7635811836115326]
# AUC_weighted                                        [0.8338834892108318]
# log_loss                                            [0.5543877687025448]
# accuracy                                            [0.7635811836115326]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_10  \
# precision_score_micro                               [0.9150227617602428]
# average_precision_score_macro                       [0.8196595960776589]
# recall_score_micro                                  [0.9150227617602428]
# average_precision_score_micro                       [0.9796972056918486]
# precision_score_macro                               [0.8136303981988294]
# precision_score_weighted                             [0.904887094301094]
# AUC_macro                                           [0.9398820406522588]
# AUC_micro                                           [0.9788144542358519]
# average_precision_score_weighted                    [0.9534894836949698]
# f1_score_weighted                                   [0.9059062049424369]
# norm_macro_recall                                  [0.40460260036640006]
# f1_score_macro                                      [0.7417439811175828]
# balanced_accuracy                                      [0.7023013001832]
# matthews_correlation                                [0.5037770829745949]
# f1_score_micro                                      [0.9150227617602428]
# weighted_accuracy                                   [0.9678357466516481]
# recall_score_macro                                     [0.7023013001832]
# recall_score_weighted                               [0.9150227617602428]
# AUC_weighted                                        [0.9398820406522588]
# log_loss                                            [0.3243792187377307]
# accuracy                                            [0.9150227617602428]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_6  \
# precision_score_micro                              [0.9028831562974203]
# average_precision_score_macro                       [0.769196899235336]
# recall_score_micro                                 [0.9028831562974203]
# average_precision_score_micro                      [0.9740908987364524]
# precision_score_macro                              [0.8049844164898143]
# precision_score_weighted                           [0.8870857866728411]
# AUC_macro                                          [0.9222052729754913]
# AUC_micro                                           [0.972820823383938]
# average_precision_score_weighted                   [0.9403566014824947]
# f1_score_weighted                                  [0.8805628453021488]
# norm_macro_recall                                 [0.22041708113595138]
# f1_score_macro                                     [0.6485586371114613]
# balanced_accuracy                                  [0.6102085405679757]
# matthews_correlation                               [0.3666709011487992]
# f1_score_micro                                     [0.9028831562974204]
# weighted_accuracy                                  [0.9755463466686412]
# recall_score_macro                                 [0.6102085405679757]
# recall_score_weighted                              [0.9028831562974203]
# AUC_weighted                                       [0.9222052729754912]
# log_loss                                          [0.22229585606904445]
# accuracy                                           [0.9028831562974203]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_11  \
# precision_score_micro                               [0.7186646433990895]
# average_precision_score_macro                       [0.7111879778394146]
# recall_score_micro                                  [0.7186646433990895]
# average_precision_score_micro                       [0.8097724068307036]
# precision_score_macro                               [0.6017334996924176]
# precision_score_weighted                            [0.8767959968938529]
# AUC_macro                                           [0.8452593975700522]
# AUC_micro                                           [0.8269358318692275]
# average_precision_score_weighted                    [0.9173771588336407]
# f1_score_weighted                                   [0.7686498927727401]
# norm_macro_recall                                   [0.4558319301579892]
# f1_score_macro                                      [0.5947556306660399]
# balanced_accuracy                                   [0.7279159650789946]
# matthews_correlation                                [0.3045435191447091]
# f1_score_micro                                      [0.7186646433990896]
# weighted_accuracy                                   [0.7163677904699863]
# recall_score_macro                                  [0.7279159650789946]
# recall_score_weighted                               [0.7186646433990895]
# AUC_weighted                                        [0.8452593975700522]
# log_loss                                            [0.5869302392861787]
# accuracy                                            [0.7186646433990895]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_14  ...  \
# precision_score_micro                               [0.9138088012139606]  ...
# average_precision_score_macro                       [0.8136182410340502]  ...
# recall_score_micro                                  [0.9138088012139606]  ...
# average_precision_score_micro                       [0.9796736019290663]  ...
# precision_score_macro                                [0.794377847854753]  ...
# precision_score_weighted                             [0.906281456407151]  ...
# AUC_macro                                           [0.9405160165750666]  ...
# AUC_micro                                           [0.9786896502494928]  ...
# average_precision_score_weighted                    [0.9523114199391448]  ...
# f1_score_weighted                                   [0.9087485655110661]  ...
# norm_macro_recall                                    [0.464810399983699]  ...
# f1_score_macro                                      [0.7582948132750074]  ...
# balanced_accuracy                                   [0.7324051999918495]  ...
# matthews_correlation                                [0.5231250045786537]  ...
# f1_score_micro                                      [0.9138088012139606]  ...
# weighted_accuracy                                   [0.9588464085130249]  ...
# recall_score_macro                                  [0.7324051999918495]  ...
# recall_score_weighted                               [0.9138088012139606]  ...
# AUC_weighted                                        [0.9405160165750666]  ...
# log_loss                                           [0.21143958465162815]  ...
# accuracy                                            [0.9138088012139606]  ...
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_8  \
# precision_score_micro                              [0.7966616084977238]
# average_precision_score_macro                      [0.7760019490722987]
# recall_score_micro                                 [0.7966616084977238]
# average_precision_score_micro                      [0.9112023690903593]
# precision_score_macro                              [0.6684924016742713]
# precision_score_weighted                           [0.9173372474203367]
# AUC_macro                                          [0.9240405151830056]
# AUC_micro                                          [0.9043802514961512]
# average_precision_score_weighted                   [0.9421192993966575]
# f1_score_weighted                                  [0.8310311064848958]
# norm_macro_recall                                  [0.7118118652136625]
# f1_score_macro                                     [0.6892846446248981]
# balanced_accuracy                                  [0.8559059326068312]
# matthews_correlation                              [0.48976502674260575]
# f1_score_micro                                     [0.7966616084977238]
# weighted_accuracy                                  [0.7819528453532839]
# recall_score_macro                                 [0.8559059326068312]
# recall_score_weighted                              [0.7966616084977238]
# AUC_weighted                                       [0.9240405151830056]
# log_loss                                           [0.3879859346018091]
# accuracy                                           [0.7966616084977238]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_9  \
# precision_score_micro                              [0.9050075872534142]
# average_precision_score_macro                      [0.7895864147291611]
# recall_score_micro                                 [0.9050075872534142]
# average_precision_score_micro                      [0.9741632043235319]
# precision_score_macro                              [0.7988842580533124]
# precision_score_weighted                            [0.889730375483731]
# AUC_macro                                          [0.9214624699220335]
# AUC_micro                                          [0.9737384780821634]
# average_precision_score_weighted                   [0.9440104615326564]
# f1_score_weighted                                  [0.8871655303279884]
# norm_macro_recall                                 [0.26780643404520177]
# f1_score_macro                                     [0.6749695323823424]
# balanced_accuracy                                  [0.6339032170226009]
# matthews_correlation                               [0.4001078038266774]
# f1_score_micro                                     [0.9050075872534142]
# weighted_accuracy                                  [0.9723154691325931]
# recall_score_macro                                 [0.6339032170226009]
# recall_score_weighted                              [0.9050075872534142]
# AUC_weighted                                       [0.9214624699220336]
# log_loss                                           [0.3408271134784256]
# accuracy                                           [0.9050075872534142]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_29  \
# precision_score_micro                               [0.9083459787556905]
# average_precision_score_macro                       [0.8003492145732944]
# recall_score_micro                                  [0.9083459787556905]
# average_precision_score_micro                       [0.9785918854295674]
# precision_score_macro                               [0.7778318057957909]
# precision_score_weighted                            [0.8995847208846137]
# AUC_macro                                           [0.9368543309493245]
# AUC_micro                                           [0.9775223875785494]
# average_precision_score_weighted                    [0.9489831959453326]
# f1_score_weighted                                   [0.9025288323944487]
# norm_macro_recall                                   [0.4302394937824976]
# f1_score_macro                                      [0.7408501014629837]
# balanced_accuracy                                   [0.7151197468912488]
# matthews_correlation                                 [0.488946245475427]
# f1_score_micro                                      [0.9083459787556905]
# weighted_accuracy                                   [0.9563188254464979]
# recall_score_macro                                  [0.7151197468912488]
# recall_score_weighted                               [0.9083459787556905]
# AUC_weighted                                        [0.9368543309493245]
# log_loss                                           [0.19127758709259576]
# accuracy                                            [0.9083459787556905]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_31  \
# precision_score_micro                               [0.9080424886191198]
# average_precision_score_macro                       [0.8099592142791322]
# recall_score_micro                                  [0.9080424886191198]
# average_precision_score_micro                       [0.9794330266148269]
# precision_score_macro                               [0.7727136465612832]
# precision_score_weighted                            [0.9022665664945998]
# AUC_macro                                           [0.9415528844283658]
# AUC_micro                                           [0.9783868048567633]
# average_precision_score_weighted                    [0.9516609246282928]
# f1_score_weighted                                   [0.9046375714873774]
# norm_macro_recall                                   [0.4701582114932563]
# f1_score_macro                                      [0.7518941836651774]
# balanced_accuracy                                   [0.7350791057466282]
# matthews_correlation                                [0.5063962091427165]
# f1_score_micro                                        [0.90804248861912]
# weighted_accuracy                                   [0.9509846180060171]
# recall_score_macro                                  [0.7350791057466282]
# recall_score_weighted                               [0.9080424886191198]
# AUC_weighted                                        [0.9415528844283658]
# log_loss                                           [0.18967836000937602]
# accuracy                                            [0.9080424886191198]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_26  \
# precision_score_micro                               [0.9119878603945372]
# average_precision_score_macro                       [0.8071742282912644]
# recall_score_micro                                  [0.9119878603945372]
# average_precision_score_micro                       [0.9794493482917321]
# precision_score_macro                               [0.7854355288470023]
# precision_score_weighted                            [0.9057755480984142]
# AUC_macro                                           [0.9407813695361835]
# AUC_micro                                            [0.978414897266977]
# average_precision_score_weighted                    [0.9509461669750866]
# f1_score_weighted                                   [0.9081566096944386]
# norm_macro_recall                                   [0.4793376641900391]
# f1_score_macro                                      [0.7597246696921418]
# balanced_accuracy                                   [0.7396688320950195]
# matthews_correlation                                 [0.523106107160623]
# f1_score_micro                                      [0.9119878603945372]
# weighted_accuracy                                   [0.9547700139704612]
# recall_score_macro                                  [0.7396688320950195]
# recall_score_weighted                               [0.9119878603945372]
# AUC_weighted                                        [0.9407813695361834]
# log_loss                                           [0.18438902755770786]
# accuracy                                            [0.9119878603945372]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_28  \
# precision_score_micro                               [0.9083459787556905]
# average_precision_score_macro                       [0.8026654255720354]
# recall_score_micro                                  [0.9083459787556905]
# average_precision_score_micro                       [0.9789996035674969]
# precision_score_macro                               [0.7764474757209578]
# precision_score_weighted                            [0.9003961976098999]
# AUC_macro                                           [0.9392202790790725]
# AUC_micro                                           [0.9779664318724512]
# average_precision_score_weighted                    [0.9497456753465818]
# f1_score_weighted                                   [0.9032508708591674]
# norm_macro_recall                                  [0.44208081178556147]
# f1_score_macro                                      [0.7443704941346683]
# balanced_accuracy                                   [0.7210404058927807]
# matthews_correlation                               [0.49439280836757793]
# f1_score_micro                                      [0.9083459787556905]
# weighted_accuracy                                   [0.9548488859675335]
# recall_score_macro                                  [0.7210404058927807]
# recall_score_weighted                               [0.9083459787556905]
# AUC_weighted                                        [0.9392202790790725]
# log_loss                                           [0.18788185943602642]
# accuracy                                            [0.9083459787556905]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_33  \
# precision_score_micro                               [0.9128983308042489]
# average_precision_score_macro                       [0.8136882418036918]
# recall_score_micro                                  [0.9128983308042489]
# average_precision_score_micro                       [0.9800297629912781]
# precision_score_macro                               [0.7883118003819065]
# precision_score_weighted                            [0.9066944678995318]
# AUC_macro                                           [0.9427754530450294]
# AUC_micro                                           [0.9790372592860384]
# average_precision_score_weighted                    [0.9526023964651265]
# f1_score_weighted                                   [0.9090427105674237]
# norm_macro_recall                                   [0.4827312182896266]
# f1_score_macro                                      [0.7618961292903779]
# balanced_accuracy                                   [0.7413656091448133]
# matthews_correlation                                [0.5275928480289197]
# f1_score_micro                                      [0.9128983308042489]
# weighted_accuracy                                   [0.9554852657106753]
# recall_score_macro                                  [0.7413656091448133]
# recall_score_weighted                               [0.9128983308042489]
# AUC_weighted                                        [0.9427754530450296]
# log_loss                                           [0.18217972151717493]
# accuracy                                            [0.9128983308042489]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_32  \
# precision_score_micro                               [0.9128983308042489]
# average_precision_score_macro                       [0.8159910956079041]
# recall_score_micro                                  [0.9128983308042489]
# average_precision_score_micro                        [0.980535695563761]
# precision_score_macro                               [0.7905852778701549]
# precision_score_weighted                            [0.9056108300409819]
# AUC_macro                                           [0.9445574394226512]
# AUC_micro                                            [0.979568343998471]
# average_precision_score_weighted                     [0.953311975239237]
# f1_score_weighted                                   [0.9081236255221017]
# norm_macro_recall                                   [0.4661533730853371]
# f1_score_macro                                      [0.7573962007511068]
# balanced_accuracy                                   [0.7330766865426686]
# matthews_correlation                                [0.5204945868078027]
# f1_score_micro                                      [0.9128983308042489]
# weighted_accuracy                                   [0.9575431809812253]
# recall_score_macro                                  [0.7330766865426686]
# recall_score_weighted                               [0.9128983308042489]
# AUC_weighted                                        [0.9445574394226512]
# log_loss                                           [0.18243072600004168]
# accuracy                                            [0.9128983308042489]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_2  \
# precision_score_micro                              [0.9116843702579667]
# average_precision_score_macro                      [0.8151093723721079]
# recall_score_micro                                 [0.9116843702579667]
# average_precision_score_micro                      [0.9806603102489483]
# precision_score_macro                              [0.7819118765348991]
# precision_score_weighted                           [0.9072720074188747]
# AUC_macro                                          [0.9450464668693166]
# AUC_micro                                           [0.979695082216353]
# average_precision_score_weighted                   [0.9531771295804466]
# f1_score_weighted                                  [0.9091539479147899]
# norm_macro_recall                                  [0.5026785366965085]
# f1_score_macro                                     [0.7653697272147331]
# balanced_accuracy                                  [0.7513392683482543]
# matthews_correlation                               [0.5323740218566827]
# f1_score_micro                                     [0.9116843702579667]
# weighted_accuracy                                  [0.9514937218005303]
# recall_score_macro                                 [0.7513392683482543]
# recall_score_weighted                              [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# log_loss                                          [0.17775706110025447]
# accuracy                                           [0.9116843702579667]
#
#                                  d3a49e17-cada-4314-b0e2-f7e879f8ed26_39
# precision_score_micro                               [0.9047040971168437]
# average_precision_score_macro                       [0.8208289635968941]
# recall_score_micro                                  [0.9047040971168437]
# average_precision_score_micro                       [0.9787933085115681]
# precision_score_macro                               [0.8651914971596115]
# precision_score_weighted                            [0.8975222869486172]
# AUC_macro                                           [0.9464996563841237]
# AUC_micro                                           [0.9776579679976789]
# average_precision_score_weighted                    [0.9545876743846854]
# f1_score_weighted                                   [0.8771032380767247]
# norm_macro_recall                                  [0.18457544452409658]
# f1_score_macro                                      [0.6285983205922727]
# balanced_accuracy                                   [0.5922877222620483]
# matthews_correlation                                [0.3671658560505202]
# f1_score_micro                                      [0.9047040971168437]
# weighted_accuracy                                   [0.9822686322733404]
# recall_score_macro                                  [0.5922877222620483]
# recall_score_weighted                               [0.9047040971168437]
# AUC_weighted                                        [0.9464996563841237]
# log_loss                                           [0.23053970909430418]
# accuracy                                            [0.9047040971168437]
#
# [21 rows x 37 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/d3a49e17-cada-4314-b0e2-f7e879f8ed26/model_data
# Downloaded azureml/d3a49e17-cada-4314-b0e2-f7e879f8ed26/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=False, is_onnx_compatible=False, observer=None, task='classification', working_dir='/m...
# ), random_state=0, reg_alpha=0, reg_lambda=1.5625, subsample=0.6, tree_method='auto'))], verbose=False)), ('4', Pipeline(memory=None, steps=[('maxabsscaler', MaxAbsScaler(copy=True)), ('extratreesclassifier', ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None, criterion='gini', max_depth=None, max_features=0.7, max_leaf_nodes=None, max_samples=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf=0.035789473684210524, min_samples_split=0.01, min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1, oob_score=False, random_state=None, verbose=0, warm_start=False))], verbose=False))], flatten_transform=None, weights=[0.14285714285714285, 0.07142857142857142, 0.2857142857142857, 0.21428571428571427, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(
#       task='classification',
#       is_onnx_compatible=False,
#       enable_feature_sweeping=True,
#       enable_dnn=False,
#       force_text_dnn=False,
#       feature_sweeping_timeout=86400,
#       featurization_config=None,
#       is_cross_validation=False,
#       feature_sweeping_config={}
#   )),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(
#       estimators=[('2', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(min_data_in_leaf=20, n_jobs=1, problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=None,
#           dataset_num_categorical=0,
#           dataset_categoricals=None,
#           pipeline_categoricals...
#           subsampling_schedule='hyperband_clip',
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None))],
#                verbose=False)), ('0', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(min_data_in_leaf=20, n_jobs=1, problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=None,
#           dataset_num_categorical=0,
#           dataset_categoricals=None,
#           pipeline_categoricals=None,
#           dataset_y_std=None,
#           dataset_uid=None,
#           subsamp...
#           subsampling_schedule='hyperband_clip',
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None))],
#                verbose=False)), ('30', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(boosting_type='goss', colsample_bytree=0.6933333333333332, learning_rate=0.1, max_bin=270, max_depth=9, min_child_weight=1, min_data_in_leaf=0.003457931034482759, min_split_gain=0.5263157894736842, n_estimators=400, n_jobs=1, num_leaves=242, problem_i...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None, reg_alpha=0.3684210526315789, reg_lambda=0.9473684210526315, subsample=1))],
#                verbose=False)), ('32', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.8, eta=0.01, gamma=0.1, max_depth=8, max_leaves=0, n_estimators=50, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_featur...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.25, reg_lambda=0.3125, subsample=0.9, tree_method='auto'))],
#                verbose=False)), ('17', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(boosting_type='goss', colsample_bytree=0.5944444444444444, learning_rate=0.026323157894736843, max_bin=310, max_depth=-1, min_child_weight=3, min_data_in_leaf=1e-05, min_split_gain=0.7894736842105263, n_estimators=50, n_jobs=1, num_leaves=131, problem...
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None, reg_alpha=0.3684210526315789, reg_lambda=1, subsample=1))],
#                verbose=False)), ('23', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.2, gamma=0, max_depth=8, max_leaves=127, n_estimators=10, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0, reg_lambda=1.5625, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('4', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('extratreesclassifier',
#                        ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                             class_weight=None, criterion='gini',
#                                             max_depth=None, max_features=0.7,
#                                             max_leaf_nodes=None, max_samples=None,
#                                             min_impurity_decrease=0.0,
#                                             min_impurity_split=None,
#                                             min_samples_leaf=0.035789473684210524,
#                                             min_samples_split=0.01,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=10, n_jobs=1,
#                                             oob_score=False, random_state=None,
#                                             verbose=0, warm_start=False))],
#                verbose=False))],
#       weights=[0.14285714285714285, 0.07142857142857142, 0.2857142857142857, 0.21428571428571427, 0.14285714285714285, 0.07142857142857142, 0.07142857142857142],
#       flatten_transform=None,
#       classification_labels=array([0, 1])
#   ))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_6f424086_f85b_11eb_bb68_eb1a6386929frow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_6f424086_f85b_11eb_bb68_eb1a6386929frow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_6f424086_f85b_11eb_bb68_eb1a6386929frow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_6f424086_f85b_11eb_bb68_eb1a6386929frow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_6f424086_f85b_11eb_bb68_eb1a6386929f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f424086_f85b_11eb_bb68_eb1a6386929flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6f424086_f85b_11eb_bb68_eb1a6386929frow0_col0" class="data row0 col0" >28752</td>
#                         <td id="T_6f424086_f85b_11eb_bb68_eb1a6386929frow0_col1" class="data row0 col1" >506</td>
#             </tr>
#             <tr>
#                         <th id="T_6f424086_f85b_11eb_bb68_eb1a6386929flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6f424086_f85b_11eb_bb68_eb1a6386929frow1_col0" class="data row1 col0" >1527</td>
#                         <td id="T_6f424086_f85b_11eb_bb68_eb1a6386929frow1_col1" class="data row1 col1" >2165</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 4e15bcd2-0066-415b-89b0-cfaab5829aa3,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/6971f5ac-8af1-446e-8034-05acea24681f/resourceGroups/aml-quickstarts-153963/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-153963/PipelineRuns/PipelineSubmit/4e15bcd2-0066-415b-89b0-cfaab5829aa3)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  d066c0b7-9c53-45cb-bcd1-869904034b5f

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
